# %% [markdown]
# Yelp API Tutorial
# Source: {
# Title: Getting Started with the Yelp API
#        Building an algorithm to help small businesses take advantage of Yelp data.
# Author: Raymond Willey
# link: https://towardsdatascience.com/getting-started-with-the-yelp-api-ac30915a77ae}

# %%
# Install Yelp API in the command line using "pip install yelpapi" 
# Import dependencies

from yelpapi import YelpAPI
import requests
from config import API_Key
from pprint import pprint
import pandas as pd

# create a yelp api instance
yelp_api = YelpAPI(API_Key)

# %%
# Fill in parameters for term, location and search_limit
term = 'Chinese Food'
location = 'Fremont, CA'
search_limit = 50

# Create the response
response = yelp_api.search_query(term = term, 
                                 location = location, 
                                 limit = search_limit)

# Check data type of response
type(response)
# Out:
# dict

# %%
pprint(response)
# Out:
# {'businesses': [{'alias': 'eastern-winds-chinese-restaurant-fremont',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.5344039,
#                                  'longitude': -121.967507},
#                  'display_phone': '(510) 651-6678',
#                  'distance': 1694.6363668531005,
#                  'id': 'UZsivgkqvhuF5hWLWsy4ZA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XuzTVR3lLlhNIb4bqVNMZA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '40723 Grimmer Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['40723 Grimmer Blvd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Eastern Winds Chinese Restaurant',
#                  'phone': '+15106516678',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 537,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/eastern-winds-chinese-restaurant-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'din-ding-dumpling-house-fremont-4',
#                  'categories': [{'alias': 'shanghainese',
#                                  'title': 'Shanghainese'}],
#                  'coordinates': {'latitude': 37.5508778939041,
#                                  'longitude': -121.980938226772},
#                  'display_phone': '(510) 797-8122',
#                  'distance': 1807.4728292155226,
#                  'id': 'yKpUdq-5cP5KJRq_MOw86Q',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B8LuMX40EGg8AZfU88m7Sg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3213 Walnut Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['3213 Walnut Ave',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Din Ding Dumpling House',
#                  'phone': '+15107978122',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1509,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/din-ding-dumpling-house-fremont-4?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'li-zhou-chinese-restaurant-fremont',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'halal', 'title': 'Halal'}],
#                  'coordinates': {'latitude': 37.56276, 'longitude': -122.01523},
#                  'display_phone': '(510) 320-5099',
#                  'distance': 3923.6025913287094,
#                  'id': 'DyCafEyqKNvVWqyhDyUcKg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v9gMbPSNPGHa1Zam1vFSQA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '36456 Fremont Blvd',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['36456 Fremont Blvd',
#                                                   'Fremont, CA 94536'],
#                               'state': 'CA',
#                               'zip_code': '94536'},
#                  'name': 'LiZhou Chinese Restaurant',
#                  'phone': '+15103205099',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 184,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/li-zhou-chinese-restaurant-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'datang-kitchen-fremont',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.57023, 'longitude': -122.03207},
#                  'display_phone': '(510) 565-1717',
#                  'distance': 5573.253973087076,
#                  'id': 'Tz0eB2eS-RBqPwYZxEcqhA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aVJ49eukYrOI_CXnTMVStQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '35041 Fremont Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['35041 Fremont Blvd',
#                                                   'Fremont, CA 94536'],
#                               'state': 'CA',
#                               'zip_code': '94536'},
#                  'name': 'Datang Kitchen',
#                  'phone': '+15105651717',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 59,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/datang-kitchen-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'ee-home-cooking-fremont-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.52637, 'longitude': -121.91849},
#                  'display_phone': '(510) 440-8822',
#                  'distance': 6109.070589888363,
#                  'id': 'vh82YTce1_YibwS72QOuVA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9RzauEf7KFb2SrBph9HENQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '43689 Mission Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['43689 Mission Blvd',
#                                                   'Fremont, CA 94539'],
#                               'state': 'CA',
#                               'zip_code': '94539'},
#                  'name': 'EE Home Cooking',
#                  'phone': '+15104408822',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 89,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/ee-home-cooking-fremont-2?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'teo-chow-noodle-shack-fremont',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.491239,
#                                  'longitude': -121.949975},
#                  'display_phone': '(510) 657-2800',
#                  'distance': 5870.89789534265,
#                  'id': '7BlSd63UNfopUCwSAQfVBw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NLTYlwcOj7jLXyYRMgr7yw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4165 Cushing Pkwy',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['4165 Cushing Pkwy',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Teo Chow Noodle Shack',
#                  'phone': '+15106572800',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 827,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/teo-chow-noodle-shack-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'pings-bistro-fremont',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.5752480619956,
#                                  'longitude': -122.044211182803},
#                  'display_phone': '(510) 744-9988',
#                  'distance': 6742.501757709532,
#                  'id': 'dtxsdk42F66vl0YnwoSWlw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l1b6Xv5xXk8rBzHglkojgg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '34145 Fremont Blvd',
#                               'address2': '',
#                               'address3': 'Charter Square Shopping Center',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['34145 Fremont Blvd',
#                                                   'Charter Square Shopping '
#                                                   'Center',
#                                                   'Fremont, CA 94555'],
#                               'state': 'CA',
#                               'zip_code': '94555'},
#                  'name': "Ping's Bistro",
#                  'phone': '+15107449988',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 260,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/pings-bistro-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'hakka-cuisine-fremont-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.5005668,
#                                  'longitude': -121.9730491},
#                  'display_phone': '(510) 668-0898',
#                  'distance': 4074.644937059748,
#                  'id': 'BOCg44e1AtrJLkleSg4s6Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KzNmqMlcMIHrkE0JShhLbg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '43755 Boscell Rd',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['43755 Boscell Rd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Hakka Cuisine',
#                  'phone': '+15106680898',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 142,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/hakka-cuisine-fremont-2?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'arzu-uyghur-cuisine-newark-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'halal', 'title': 'Halal'},
#                                 {'alias': 'uzbek', 'title': 'Uzbek'}],
#                  'coordinates': {'latitude': 37.523361,
#                                  'longitude': -122.006549},
#                  'display_phone': '(510) 896-8027',
#                  'distance': 2195.6638927984363,
#                  'id': 'WzuG9t8ZcbHdG0YyGLQe1w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pUfLj8asy771KXUNF44qzg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '39119 Cedar Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['39119 Cedar Blvd',
#                                                   'Newark, CA 94560'],
#                               'state': 'CA',
#                               'zip_code': '94560'},
#                  'name': 'Arzu Uyghur Cuisine',
#                  'phone': '+15108968027',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 103,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/arzu-uyghur-cuisine-newark-2?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'spices-fremont',
#                  'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#                  'coordinates': {'latitude': 37.531368,
#                                  'longitude': -121.936132},
#                  'display_phone': '(510) 270-8828',
#                  'distance': 4479.589644985262,
#                  'id': 'vkrt2AP-HgZcNS_wd_DObw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gh-c0LRws3zX2twSyyJ5Ow/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1616 Washington Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['1616 Washington Blvd',
#                                                   'Fremont, CA 94539'],
#                               'state': 'CA',
#                               'zip_code': '94539'},
#                  'name': 'Spices!',
#                  'phone': '+15102708828',
#                  'price': '$$$',
#                  'rating': 3.5,
#                  'review_count': 425,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/spices-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'tai-pan-bbq-express-dim-sum-fremont-3',
#                  'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'dimsum', 'title': 'Dim Sum'}],
#                  'coordinates': {'latitude': 37.5450308,
#                                  'longitude': -121.9809375},
#                  'display_phone': '(510) 739-1868',
#                  'distance': 1273.9928344746095,
#                  'id': 'MOjuDBWqKVZ7vmPyuwuLhw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/B5X25SXEYGnjNOWpJhLabw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '39486 Fremont Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['39486 Fremont Blvd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Tai Pan BBQ Express Dim Sum',
#                  'phone': '+15107391868',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 339,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/tai-pan-bbq-express-dim-sum-fremont-3?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'ok-noodle-newark-3',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 37.537844,
#                                  'longitude': -122.017703},
#                  'display_phone': '(510) 818-9928',
#                  'distance': 2749.006008640292,
#                  'id': 'eCs2w1_XtDp51jYBsGulWQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ck40i4_36YultlHXaz-SPQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5492 Central Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['5492 Central Ave',
#                                                   'Newark, CA 94560'],
#                               'state': 'CA',
#                               'zip_code': '94560'},
#                  'name': 'OK Noodle',
#                  'phone': '+15108189928',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 471,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/ok-noodle-newark-3?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'new-yong-kang-fremont',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'cantonese', 'title': 'Cantonese'}],
#                  'coordinates': {'latitude': 37.534409,
#                                  'longitude': -121.960705},
#                  'display_phone': '(510) 252-9926',
#                  'distance': 2293.6554628904814,
#                  'id': 'x6wdnhOOqJp3o_kbPOuLaA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FZrLf-nO_9kG_9dU7JP7Hw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '40900 Fremont Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['40900 Fremont Blvd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'New Yong Kang',
#                  'phone': '+15102529926',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 380,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/new-yong-kang-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'tasty-chinese-kitchen-newark',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.5230818456164,
#                                  'longitude': -121.998411230743},
#                  'display_phone': '(510) 505-9981',
#                  'distance': 1704.7917615018348,
#                  'id': 'nuopHlysRJSfJCKy8zyH5w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/v_uVX4TUYr11Sy_c6BI2-w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5576 Newpark Mall',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['5576 Newpark Mall',
#                                                   'Newark, CA 94560'],
#                               'state': 'CA',
#                               'zip_code': '94560'},
#                  'name': 'Tasty Chinese Kitchen',
#                  'phone': '+15105059981',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 381,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/tasty-chinese-kitchen-newark?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'hunan-cuisine-四姐川湘-fremont-19',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.519481,
#                                  'longitude': -121.989089},
#                  'display_phone': '(510) 687-1222',
#                  'distance': 1769.0554512493218,
#                  'id': 'pYgY5cYRjB4monH3cx6Xqg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HyiwyfZ6W3zddLWMUTMvLQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6004 Stevenson Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['6004 Stevenson Blvd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Hunan Cuisine 四姐川湘',
#                  'phone': '+15106871222',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 199,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/hunan-cuisine-%E5%9B%9B%E5%A7%90%E5%B7%9D%E6%B9%98-fremont-19?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'northwest-china-cuisine-fremont',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.51838, 'longitude': -121.98959},
#                  'display_phone': '(510) 509-6088',
#                  'distance': 1900.9683809166875,
#                  'id': 'b7d2RxhFeRUl1CMvT_krIw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iKH5nLoXU7y5UVKoariL1A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6096 Stevenson Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['6096 Stevenson Blvd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Northwest China Cuisine',
#                  'phone': '+15105096088',
#                  'rating': 4.0,
#                  'review_count': 46,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/northwest-china-cuisine-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'shanghai-flavor-fremont',
#                  'categories': [{'alias': 'shanghainese',
#                                  'title': 'Shanghainese'}],
#                  'coordinates': {'latitude': 37.49363, 'longitude': -121.93116},
#                  'display_phone': '(510) 353-1013',
#                  'distance': 6759.383803813519,
#                  'id': 'UcpHsvR9XrVXF8qkm7ZHbQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MVU0TQlMSZTuQQ1kBocWPg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '46132 Warm Springs Blvd',
#                               'address2': 'Ste 165',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['46132 Warm Springs Blvd',
#                                                   'Ste 165',
#                                                   'Fremont, CA 94539'],
#                               'state': 'CA',
#                               'zip_code': '94539'},
#                  'name': 'Shanghai Flavor',
#                  'phone': '+15103531013',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 206,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/shanghai-flavor-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'sweet-garden-fremont',
#                  'categories': [{'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'},
#                                 {'alias': 'ramen', 'title': 'Ramen'}],
#                  'coordinates': {'latitude': 37.5438591450212,
#                                  'longitude': -121.981836226954},
#                  'display_phone': '(510) 771-9518',
#                  'distance': 1046.0377098819436,
#                  'id': 'p5uqf2ujdisFkjkMDAT9Ow',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n8y8BTb8O40zaLvAEGLgCQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '39473 Fremont Blvd',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['39473 Fremont Blvd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Sweet Garden',
#                  'phone': '+15107719518',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 363,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/sweet-garden-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'hong-kong-chef-fremont',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.49283, 'longitude': -121.93018},
#                  'display_phone': '(510) 573-4066',
#                  'distance': 6795.329908183012,
#                  'id': 'Sfb9h2CYr_fZMeZ5MqEM2w',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FS8b-9jzaOOt__9OodTT5Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '46356 Warm Springs Blvd',
#                               'address2': 'Ste 848',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['46356 Warm Springs Blvd',
#                                                   'Ste 848',
#                                                   'Fremont, CA 94539'],
#                               'state': 'CA',
#                               'zip_code': '94539'},
#                  'name': 'Hong Kong Chef',
#                  'phone': '+15105734066',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 238,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/hong-kong-chef-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'shanghai-noodle-house-fremont',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 37.536104,
#                                  'longitude': -121.96512},
#                  'display_phone': '(510) 668-1007',
#                  'distance': 1904.5307612528957,
#                  'id': '7oInIzs1ZNSA4llr9_pvSA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/B-nl5lHQog15MaRSbSpF2g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '40575 Fremont Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['40575 Fremont Blvd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Shanghai Noodle House',
#                  'phone': '+15106681007',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 317,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/shanghai-noodle-house-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'shang-cafe-fremont-3',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'},
#                                 {'alias': 'soup', 'title': 'Soup'}],
#                  'coordinates': {'latitude': 37.5000633371133,
#                                  'longitude': -121.973736784017},
#                  'display_phone': '(510) 656-1638',
#                  'distance': 4078.9124907155274,
#                  'id': '7mX6-odwQvSX2XUhOGMrYA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lszBxQDQlQZFFqYTMS9m-Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '43749 Boscell Rd',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['43749 Boscell Rd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Shang Cafe',
#                  'phone': '+15106561638',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 117,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/shang-cafe-fremont-3?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'ck-cafe-fremont',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#                  'coordinates': {'latitude': 37.522905,
#                                  'longitude': -121.971225},
#                  'display_phone': '(510) 270-8041',
#                  'distance': 1937.3472545781558,
#                  'id': 'yGPrRXwbAHA9XQ4JaLY5RA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aaCkiX1Oy01Dij2ai9nleg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '41200 Blacow Rd',
#                               'address2': 'Ste K',
#                               'address3': None,
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['41200 Blacow Rd',
#                                                   'Ste K',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'CK Cafe',
#                  'phone': '+15102708041',
#                  'rating': 4.0,
#                  'review_count': 26,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/ck-cafe-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'bings-dumpling-fremont',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 37.5752032935909,
#                                  'longitude': -122.040460221469},
#                  'display_phone': '(510) 320-5360',
#                  'distance': 6494.113036125059,
#                  'id': 'oa0k4i-zi_TdE-DQvCJNmg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y-ts-X1Ma3AufHb-mPN92A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '34360 Fremont Blvd',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['34360 Fremont Blvd',
#                                                   'Fremont, CA 94555'],
#                               'state': 'CA',
#                               'zip_code': '94555'},
#                  'name': "Bing's Dumpling",
#                  'phone': '+15103205360',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 735,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/bings-dumpling-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'emperor-dynasty-banquet-newark',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'fooddeliveryservices',
#                                  'title': 'Food Delivery Services'}],
#                  'coordinates': {'latitude': 37.5267493517,
#                                  'longitude': -122.000720397},
#                  'display_phone': '(510) 650-8630',
#                  'distance': 1558.4648867473493,
#                  'id': 'vu9iWvr8SUtpzQratYasXw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8D5rIjDVkPaoHz9dh9zdrQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2086 Newpark Mall',
#                               'address2': 'Ste 1096',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['2086 Newpark Mall',
#                                                   'Ste 1096',
#                                                   'Newark, CA 94560'],
#                               'state': 'CA',
#                               'zip_code': '94560'},
#                  'name': 'Emperor Dynasty Banquet',
#                  'phone': '+15106508630',
#                  'rating': 5.0,
#                  'review_count': 8,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/emperor-dynasty-banquet-newark?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'eden-silk-road-cuisine-fremont-8',
#                  'categories': [{'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'halal', 'title': 'Halal'}],
#                  'coordinates': {'latitude': 37.554399,
#                                  'longitude': -121.980297},
#                  'display_phone': '(510) 505-9255',
#                  'distance': 2199.8263272981817,
#                  'id': 'ZbYi9lyepro0Tv-ZIG5dOQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LOUIgEhiQAp6fl8-KMMLMg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '39144 Paseo Padre Pkwy',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['39144 Paseo Padre Pkwy',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Eden Silk Road Cuisine',
#                  'phone': '+15105059255',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 491,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/eden-silk-road-cuisine-fremont-8?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'xian-kitchen-fremont',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.5762011,
#                                  'longitude': -122.0437958},
#                  'display_phone': '(510) 565-1616',
#                  'distance': 6769.47014721664,
#                  'id': '1r84Hc1Rc9psL5YiAF3jNg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/io5cXLtuPLNI7Xj6QCUGzg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '34137 Fremont Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['34137 Fremont Blvd',
#                                                   'Fremont, CA 94555'],
#                               'state': 'CA',
#                               'zip_code': '94555'},
#                  'name': 'Xian Kitchen',
#                  'phone': '+15105651616',
#                  'rating': 3.5,
#                  'review_count': 46,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/xian-kitchen-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'old-taro-fremont-4',
#                  'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#                                 {'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.55631, 'longitude': -122.01464},
#                  'display_phone': '(510) 912-3005',
#                  'distance': 3361.3569582663276,
#                  'id': '-9uDtOiVlmKwXxNJ5vznaA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ezHudB3pPLcVYqeWkKUFNA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4370 Thornton Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['4370 Thornton Ave',
#                                                   'Fremont, CA 94536'],
#                               'state': 'CA',
#                               'zip_code': '94536'},
#                  'name': 'Old Taro',
#                  'phone': '+15109123005',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 159,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/old-taro-fremont-4?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'yummy-crab麻辣小站-fremont',
#                  'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#                                 {'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.492835,
#                                  'longitude': -121.930182},
#                  'display_phone': '(510) 249-5688',
#                  'distance': 6920.914127694501,
#                  'id': 'HMEFuAQfSl2r9wPeOLojmQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I3p-6ptcsSNH_MB33xu5Xg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '46260 Warm Springs Blvd',
#                               'address2': 'Ste 545',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['46260 Warm Springs Blvd',
#                                                   'Ste 545',
#                                                   'Fremont, CA 94539'],
#                               'state': 'CA',
#                               'zip_code': '94539'},
#                  'name': 'Yummy Crab麻辣小站',
#                  'phone': '+15102495688',
#                  'rating': 3.5,
#                  'review_count': 39,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/yummy-crab%E9%BA%BB%E8%BE%A3%E5%B0%8F%E7%AB%99-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'yums-bistro-fremont',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.56725, 'longitude': -122.05245},
#                  'display_phone': '(510) 745-8866',
#                  'distance': 6773.466117248001,
#                  'id': 'gpCZaKXwHEKWorqFzNPKvA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/disgFsecJN0J6GbTQmBIKw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4906 Paseo Padre Pkwy',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['4906 Paseo Padre Pkwy',
#                                                   'Fremont, CA 94555'],
#                               'state': 'CA',
#                               'zip_code': '94555'},
#                  'name': "Yum's Bistro",
#                  'phone': '+15107458866',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 227,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/yums-bistro-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'du-xiao-yue-fremont-2',
#                  'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#                                 {'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.4907, 'longitude': -121.9497},
#                  'display_phone': '(510) 661-9316',
#                  'distance': 5883.381290774244,
#                  'id': 'My9Nyw_Oc2h01b85Wn7PRw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nqNrbzDxS6DX2ZexMmtErg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4161 Cushing Pkwy',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['4161 Cushing Pkwy',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Du Xiao Yue',
#                  'phone': '+15106619316',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 130,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/du-xiao-yue-fremont-2?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'shinry-lamian-fremont-3',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'noodles', 'title': 'Noodles'}],
#                  'coordinates': {'latitude': 37.56291, 'longitude': -122.01009},
#                  'display_phone': '(510) 792-6660',
#                  'distance': 3717.233932838973,
#                  'id': 'q4TFULSMVoebvbJfnCYzmQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YFiLIx1bV_8WB25Wprx44Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3625 Thornton Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['3625 Thornton Ave',
#                                                   'Fremont, CA 94536'],
#                               'state': 'CA',
#                               'zip_code': '94536'},
#                  'name': 'Shinry Lamian',
#                  'phone': '+15107926660',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 126,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/shinry-lamian-fremont-3?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'happy-kitchen-newark',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
# ...
#                 {'alias': 'king-of-dumplings-newark',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.522435903083,
#                                  'longitude': -122.00463237061},
#                  'display_phone': '(510) 713-2800',
#                  'distance': 2130.9348849749836,
#                  'id': 'NuFL7VZgFEgkspJmfvnNeQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7fMJcAy3zrtBXCmAdhFSqw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '39229 Cedar Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['39229 Cedar Blvd',
#                                                   'Newark, CA 94560'],
#                               'state': 'CA',
#                               'zip_code': '94560'},
#                  'name': 'King Of Dumplings',
#                  'phone': '+15107132800',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 277,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/king-of-dumplings-newark?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'bks-bistro-fremont',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'cantonese', 'title': 'Cantonese'}],
#                  'coordinates': {'latitude': 37.547095,
#                                  'longitude': -121.972661},
#                  'display_phone': '(510) 770-8818',
#                  'distance': 1804.9437280947013,
#                  'id': '6fsQBl5UzfeOQp9dytgujA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Jp_yLBKcVLeSW8eC-A3lhw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3113 Stevenson Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['3113 Stevenson Blvd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': "BK's Bistro",
#                  'phone': '+15107708818',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 824,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/bks-bistro-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'general-pot-fremont-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.5002316101191,
#                                  'longitude': -121.973712444305},
#                  'display_phone': '(510) 657-8188',
#                  'distance': 4061.5584365443024,
#                  'id': '-KMYD5GXVGUaEhTTh9f33g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ivcO8xgSsCRFgx4jP_-YWg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '43767 Boscell Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['43767 Boscell Rd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'General Pot',
#                  'phone': '+15106578188',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 144,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/general-pot-fremont-2?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'fire-point-bbq-and-noodle-fremont-2',
#                  'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.5761663,
#                                  'longitude': -122.0437406},
#                  'display_phone': '(510) 791-3036',
#                  'distance': 6792.59220231696,
#                  'id': 'ZIFcK_6l3ZQhn7NMhNLsDA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rNaZfkdsELWyDPTtJiPRMg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '34129 Fremont Blvd',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['34129 Fremont Blvd',
#                                                   'Fremont, CA 94555'],
#                               'state': 'CA',
#                               'zip_code': '94555'},
#                  'name': 'Fire Point Bbq & Noodle',
#                  'phone': '+15107913036',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 107,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/fire-point-bbq-and-noodle-fremont-2?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'house-of-dumplings-union-city-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 37.5915, 'longitude': -122.00294},
#                  'display_phone': '(510) 324-8868',
#                  'distance': 6421.567688884989,
#                  'id': 'i5RlRZwPavkbKXdB_0zOHA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E0yi_p4VqQCCNzOOQ0OQJg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '109 Appian Way',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Union City',
#                               'country': 'US',
#                               'display_address': ['109 Appian Way',
#                                                   'Union City, CA 94587'],
#                               'state': 'CA',
#                               'zip_code': '94587'},
#                  'name': 'House of Dumplings',
#                  'phone': '+15103248868',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 990,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/house-of-dumplings-union-city-2?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'i-shanghai-delight-fremont-3',
#                  'categories': [{'alias': 'shanghainese',
#                                  'title': 'Shanghainese'}],
#                  'coordinates': {'latitude': 37.5193723223453,
#                                  'longitude': -121.990044237496},
#                  'display_phone': '(510) 709-1196',
#                  'distance': 1792.9937131406543,
#                  'id': 'wsItLDFApR8eR0evXWyPNg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fg3ZUHmZWwZJeXCBrmOEMw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6016 Stevenson Blvd',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['6016 Stevenson Blvd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'I-Shanghai Delight',
#                  'phone': '+15107091196',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 424,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/i-shanghai-delight-fremont-3?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'asian-pearl-seafood-restaurant-fremont',
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'cantonese', 'title': 'Cantonese'}],
#                  'coordinates': {'latitude': 37.5009548,
#                                  'longitude': -121.973572},
#                  'display_phone': '(510) 979-1368',
#                  'distance': 3981.7976659710275,
#                  'id': 'OgoHoAQEWA-6jlaxx-I0IQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QGXkt0m9Fu4JopXertqTtw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '43635 Boscell Rd',
#                               'address2': '',
#                               'address3': 'Pacific Commons Shopping Center',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['43635 Boscell Rd',
#                                                   'Pacific Commons Shopping '
#                                                   'Center',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Asian Pearl Seafood Restaurant',
#                  'phone': '+15109791368',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 1001,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/asian-pearl-seafood-restaurant-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'full-house-dumpling-fremont-2',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#                  'coordinates': {'latitude': 37.5185752748918,
#                                  'longitude': -121.989232971634},
#                  'display_phone': '(510) 230-0773',
#                  'distance': 1870.5630515298071,
#                  'id': 'cXbrc22cJaLRpJ0oKRdERA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aniwkyU2eqE7DwygsXw_xA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '6092 Stevenson Blvd',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['6092 Stevenson Blvd',
#                                                   'Fremont, CA 94538'],
#                               'state': 'CA',
#                               'zip_code': '94538'},
#                  'name': 'Full House Dumpling',
#                  'phone': '+15102300773',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 203,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/full-house-dumpling-fremont-2?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'ho-chow-restaurant-fremont',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 37.4767594740515,
#                                  'longitude': -121.921156109449},
#                  'display_phone': '(510) 657-0683',
#                  'distance': 8704.013004041755,
#                  'id': '4H86Ob5uf4GLNVRzunBNSA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rsiCWb-jjFlRfN7dYpuzxw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '47966 Warm Springs Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Fremont',
#                               'country': 'US',
#                               'display_address': ['47966 Warm Springs Blvd',
#                                                   'Fremont, CA 94539'],
#                               'state': 'CA',
#                               'zip_code': '94539'},
#                  'name': 'Ho Chow Restaurant',
#                  'phone': '+15106570683',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 339,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/ho-chow-restaurant-fremont?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'},
#                 {'alias': 'asia-express-newark-4',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'burmese', 'title': 'Burmese'},
#                                 {'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 37.54046, 'longitude': -122.02623},
#                  'display_phone': '(510) 742-8818',
#                  'distance': 3541.999812171393,
#                  'id': '9afeWzkyA-B_cVjtHkRetQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O4ZuRR16QSRf3UnvaS7YcA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5672 Thornton Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['5672 Thornton Ave',
#                                                   'Newark, CA 94560'],
#                               'state': 'CA',
#                               'zip_code': '94560'},
#                  'name': 'Asia Express',
#                  'phone': '+15107428818',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 175,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/asia-express-newark-4?adjust_creative=qZgnuEk1wNIwkDh04-K-rQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qZgnuEk1wNIwkDh04-K-rQ'}],
#  'region': {'center': {'latitude': 37.53527676006081,
#                        'longitude': -121.9866943359375}},
#  'total': 650}

# %%
# Check key of response dictionary (Alternative to scroll through text to look for keys)
print(response.keys())
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
# Set list of keys as column names
cols = list(response['businesses'][0].keys())

# Ceate a DataFrame
data = pd.DataFrame(columns=cols)

for biz in response['businesses']:
    data = data.append(biz, ignore_index=True)
data.head()
# Out:
#                        id                                     alias  \
# 0  UZsivgkqvhuF5hWLWsy4ZA  eastern-winds-chinese-restaurant-fremont
# 1  yKpUdq-5cP5KJRq_MOw86Q         din-ding-dumpling-house-fremont-4
# 2  DyCafEyqKNvVWqyhDyUcKg        li-zhou-chinese-restaurant-fremont
# 3  Tz0eB2eS-RBqPwYZxEcqhA                    datang-kitchen-fremont
# 4  vh82YTce1_YibwS72QOuVA                 ee-home-cooking-fremont-2
#
#                                name  \
# 0  Eastern Winds Chinese Restaurant
# 1           Din Ding Dumpling House
# 2         LiZhou Chinese Restaurant
# 3                    Datang Kitchen
# 4                   EE Home Cooking
#
#                                            image_url is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/XuzTVR...     False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/B8LuMX...     False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/v9gMbP...     False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/aVJ49e...     False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/9RzauE...     False
#
#                                                  url review_count  \
# 0  https://www.yelp.com/biz/eastern-winds-chinese...          537
# 1  https://www.yelp.com/biz/din-ding-dumpling-hou...         1509
# 2  https://www.yelp.com/biz/li-zhou-chinese-resta...          184
# 3  https://www.yelp.com/biz/datang-kitchen-fremon...           59
# 4  https://www.yelp.com/biz/ee-home-cooking-fremo...           89
#
#                                           categories  rating  \
# 0         [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 1  [{'alias': 'shanghainese', 'title': 'Shanghain...     4.0
# 2  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.5
# 3         [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 4         [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 37.5344039, 'longitude': -121.967...  [delivery, pickup]
# 1  {'latitude': 37.5508778939041, 'longitude': -1...  [pickup, delivery]
# 2    {'latitude': 37.56276, 'longitude': -122.01523}  [pickup, delivery]
# 3    {'latitude': 37.57023, 'longitude': -122.03207}          [delivery]
# 4    {'latitude': 37.52637, 'longitude': -121.91849}          [delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '40723 Grimmer Blvd', 'address2':...  +15106516678
# 1    $$  {'address1': '3213 Walnut Ave', 'address2': ''...  +15107978122
# 2    $$  {'address1': '36456 Fremont Blvd', 'address2':...  +15103205099
# 3    $$  {'address1': '35041 Fremont Blvd', 'address2':...  +15105651717
# 4    $$  {'address1': '43689 Mission Blvd', 'address2':...  +15104408822
#
#     display_phone     distance
# 0  (510) 651-6678  1694.636367
# 1  (510) 797-8122  1807.472829
# 2  (510) 320-5099  3923.602591
# 3  (510) 565-1717  5573.253973
# 4  (510) 440-8822  6109.070590

# %%
# Create ned dataframe with [id, name, url, review_count, rating, transactions and price]

data_new = data[['name', 'url', 'review_count', 'rating', 'transactions','price']]

# %%
data_new.head()
# Out:
#                                name  \
# 0  Eastern Winds Chinese Restaurant
# 1           Din Ding Dumpling House
# 2         LiZhou Chinese Restaurant
# 3                    Datang Kitchen
# 4                   EE Home Cooking
#
#                                                  url review_count  rating  \
# 0  https://www.yelp.com/biz/eastern-winds-chinese...          537     4.0
# 1  https://www.yelp.com/biz/din-ding-dumpling-hou...         1509     4.0
# 2  https://www.yelp.com/biz/li-zhou-chinese-resta...          184     3.5
# 3  https://www.yelp.com/biz/datang-kitchen-fremon...           59     4.5
# 4  https://www.yelp.com/biz/ee-home-cooking-fremo...           89     4.5
#
#          transactions price
# 0  [delivery, pickup]     $
# 1  [pickup, delivery]    $$
# 2  [pickup, delivery]    $$
# 3          [delivery]    $$
# 4          [delivery]    $$

# %%
# More analysis to follow.......
